# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "last"

import argparse
from ddpg_torch.ddpg_torch import Agent
import gym
import numpy as np
from lifting_rl.linkage_env import LinkageEnv

from livelossplot import PlotLosses

# %%
params = {
    "N_LINKS": 5,
    "PARAM_VALS": np.array([9.81], dtype=np.float32),
    "OBS_LOW": np.array([0.5, 1, -0.5, -2.5, -2], dtype=np.float32),
    "OBS_HIGH": np.array([2.5, 3.1, 2.2, -0.3, -0.2], dtype=np.float32),
    "SPEED_LIMIT": 8,
    "ACT_LIMIT": 1000,
    "TIME_STEP": 0.01,
    "VIDEO_FPS": 30,
}

# %%
env = LinkageEnv(params, verbose=0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-8b113e5d18e5> in <module>
# ----> 1 env = LinkageEnv(params, verbose=0)
#
# ~/git/human-body-model-dynamics/lifting_rl/linkage_env.py in __init__(self, w_params, verbose)
#      13     metadata = {"render.modes": ["human"]}
#      14     def __init__(self, w_params: dict, verbose: bool = False):
# ---> 15         M, F, m_params = kane(n=w_params["N_LINKS"], hands_load=False)
#      16         self.M_func_nhl = lambdify(m_params, M)
#      17         self.F_func_nhl = lambdify(m_params, F)
#
# ~/git/human-body-model-dynamics/lifting_rl/n_linkage.py in kane(n, mode, hands_load)
#      60     km = KanesMethod(N, q_ind=q, u_ind=u, kd_eqs=kindiffs)
#      61     fr, frstar = km.kanes_equations(phys_objs, loads=loads)
# ---> 62     fr.simplify()
#      63     frstar.simplify()
#      64     dynamic = q + u + f
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/matrices/dense.py in simplify(self, **kwargs)
#     578         """
#     579         for i in range(len(self._mat)):
# --> 580             self._mat[i] = _simplify(self._mat[i], **kwargs)
#     581
#     582     def zip_row_op(self, i, k, f):
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/simplify/simplify.py in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     663
#     664     if expr.has(TrigonometricFunction, HyperbolicFunction):
# --> 665         expr = trigsimp(expr, deep=True)
#     666
#     667     if expr.has(log):
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/simplify/trigsimp.py in trigsimp(expr, **opts)
#     506                    }[method]
#     507
# --> 508     return trigsimpfunc(expr)
#     509
#     510
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/simplify/trigsimp.py in <lambda>(x)
#     499     trigsimpfunc = {
#     500         'fu': (lambda x: fu(x, **opts)),
# --> 501         'matching': (lambda x: futrig(x)),
#     502         'groebner': (lambda x: groebnersimp(x, **opts)),
#     503         'combined': (lambda x: futrig(groebnersimp(x,
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/simplify/trigsimp.py in futrig(e, hyper, **kwargs)
#    1098
#    1099     old = e
# -> 1100     e = bottom_up(e, _futrig)
#    1101
#    1102     if hyper and e.has(HyperbolicFunction):
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1157             if args != rv.args:
#    1158                 rv = rv.func(*args)
# -> 1159             rv = F(rv)
#    1160         elif atoms:
#    1161             rv = F(rv)
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/simplify/trigsimp.py in _futrig(e)
#    1166             factor_terms, TR12(x), trigs)],  # expand tan of sum
#    1167         )]
# -> 1168     e = greedy(tree, objective=Lops)(e)
#    1169
#    1170     if coeff is not None:
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/strategies/core.py in minrule(expr)
#     112
#     113     def minrule(expr):
# --> 114         return min([rule(expr) for rule in rules], key=objective)
#     115     return minrule
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/strategies/core.py in <listcomp>(.0)
#     112
#     113     def minrule(expr):
# --> 114         return min([rule(expr) for rule in rules], key=objective)
#     115     return minrule
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/strategies/core.py in chain_rl(expr)
#      42     def chain_rl(expr):
#      43         for rule in rules:
# ---> 44             expr = rule(expr)
#      45         return expr
#      46     return chain_rl
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/simplify/trigsimp.py in <lambda>(x)
#    1134         TR1,  # sec-csc -> cos-sin
#    1135         TR12,  # expand tan of sum
# -> 1136         lambda x: _eapply(factor, x, trigs),
#    1137         TR2,  # tan-cot -> sin-cos
#    1138         [identity, lambda x: _eapply(_mexpand, x, trigs)],
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/simplify/trigsimp.py in _eapply(func, e, cond)
#    1191         return e
#    1192     if _is_Expr(e) or not e.args:
# -> 1193         return func(e)
#    1194     return e.func(*[
#    1195         _eapply(func, ei) if (cond is None or cond(ei)) else ei
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/polytools.py in factor(f, deep, *gens, **args)
#    6368
#    6369     try:
# -> 6370         return _generic_factor(f, gens, args, method='factor')
#    6371     except PolynomialError as msg:
#    6372         if not f.is_commutative:
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/polytools.py in _generic_factor(expr, gens, args, method)
#    6040     opt = options.build_options(gens, args)
#    6041     opt['fraction'] = fraction
# -> 6042     return _symbolic_factor(sympify(expr), opt, method)
#    6043
#    6044
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/polytools.py in _symbolic_factor(expr, opt, method)
#    5980         if hasattr(expr,'_eval_factor'):
#    5981             return expr._eval_factor()
# -> 5982         coeff, factors = _symbolic_factor_list(together(expr, fraction=opt['fraction']), opt, method)
#    5983         return _keep_coeff(coeff, _factors_product(factors))
#    5984     elif hasattr(expr, 'args'):
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/polytools.py in _symbolic_factor_list(expr, opt, method)
#    5945             func = getattr(poly, method + '_list')
#    5946
# -> 5947             _coeff, _factors = func()
#    5948             if _coeff is not S.One:
#    5949                 if exp.is_Integer:
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/polytools.py in factor_list(f)
#    3314         if hasattr(f.rep, 'factor_list'):
#    3315             try:
# -> 3316                 coeff, factors = f.rep.factor_list()
#    3317             except DomainError:
#    3318                 return S.One, [(f, 1)]
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/polyclasses.py in factor_list(f)
#     793     def factor_list(f):
#     794         """Returns a list of irreducible factors of ``f``. """
# --> 795         coeff, factors = dmp_factor_list(f.rep, f.lev, f.dom)
#     796         return coeff, [ (f.per(g), k) for g, k in factors ]
#     797
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/factortools.py in dmp_factor_list(f, u, K0)
#    1409         if K.is_ZZ:
#    1410             levels, f, v = dmp_exclude(f, u, K)
# -> 1411             coeff, factors = dmp_zz_factor(f, v, K)
#    1412
#    1413             for i, (f, k) in enumerate(factors):
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/factortools.py in dmp_zz_factor(f, u, K)
#    1140         return cont, []
#    1141
# -> 1142     G, g = dmp_primitive(g, u, K)
#    1143
#    1144     factors = []
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_primitive(f, u, K)
#    1816
#    1817     """
# -> 1818     cont, v = dmp_content(f, u, K), u - 1
#    1819
#    1820     if dmp_zero_p(f, u) or dmp_one_p(cont, v, K):
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_content(f, u, K)
#    1791
#    1792     for c in f[1:]:
# -> 1793         cont = dmp_gcd(cont, c, v, K)
#    1794
#    1795         if dmp_one_p(cont, v, K):
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_gcd(f, g, u, K)
#    1623
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#    1626
#    1627
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1582
#    1583     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1585
#    1586     return (dmp_inflate(h, J, u, K),
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1551         if K.is_ZZ and query('USE_HEU_GCD'):
#    1552             try:
# -> 1553                 return dmp_zz_heu_gcd(f, g, u, K)
#    1554             except HeuristicGCDFailed:
#    1555                 pass
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1309         return dup_zz_heu_gcd(f, g, K)
#    1310
# -> 1311     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1312
#    1313     if result is not None:
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     909         return dmp_one(u, K), f, g
#     910     elif query('USE_SIMPLIFY_GCD'):
# --> 911         return _dmp_simplify_gcd(f, g, u, K)
#     912     else:
#     913         return None
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     951             G = dmp_content(g, u, K)
#     952         else:
# --> 953             F = dmp_content(f, u, K)
#     954             G = dmp_LC(g, K)
#     955
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_content(f, u, K)
#    1791
#    1792     for c in f[1:]:
# -> 1793         cont = dmp_gcd(cont, c, v, K)
#    1794
#    1795         if dmp_one_p(cont, v, K):
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_gcd(f, g, u, K)
#    1623
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#    1626
#    1627
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1582
#    1583     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1585
#    1586     return (dmp_inflate(h, J, u, K),
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1551         if K.is_ZZ and query('USE_HEU_GCD'):
#    1552             try:
# -> 1553                 return dmp_zz_heu_gcd(f, g, u, K)
#    1554             except HeuristicGCDFailed:
#    1555                 pass
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1309         return dup_zz_heu_gcd(f, g, K)
#    1310
# -> 1311     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1312
#    1313     if result is not None:
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     909         return dmp_one(u, K), f, g
#     910     elif query('USE_SIMPLIFY_GCD'):
# --> 911         return _dmp_simplify_gcd(f, g, u, K)
#     912     else:
#     913         return None
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     949         if not df:
#     950             F = dmp_LC(f, K)
# --> 951             G = dmp_content(g, u, K)
#     952         else:
#     953             F = dmp_content(f, u, K)
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_content(f, u, K)
#    1791
#    1792     for c in f[1:]:
# -> 1793         cont = dmp_gcd(cont, c, v, K)
#    1794
#    1795         if dmp_one_p(cont, v, K):
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_gcd(f, g, u, K)
#    1623
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#    1626
#    1627
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1582
#    1583     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1585
#    1586     return (dmp_inflate(h, J, u, K),
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1551         if K.is_ZZ and query('USE_HEU_GCD'):
#    1552             try:
# -> 1553                 return dmp_zz_heu_gcd(f, g, u, K)
#    1554             except HeuristicGCDFailed:
#    1555                 pass
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1309         return dup_zz_heu_gcd(f, g, K)
#    1310
# -> 1311     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1312
#    1313     if result is not None:
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     909         return dmp_one(u, K), f, g
#     910     elif query('USE_SIMPLIFY_GCD'):
# --> 911         return _dmp_simplify_gcd(f, g, u, K)
#     912     else:
#     913         return None
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     955
#     956     v = u - 1
# --> 957     h = dmp_gcd(F, G, v, K)
#     958
#     959     cff = [ dmp_quo(cf, h, v, K) for cf in f ]
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_gcd(f, g, u, K)
#    1623
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#    1626
#    1627
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1582
#    1583     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1585
#    1586     return (dmp_inflate(h, J, u, K),
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1551         if K.is_ZZ and query('USE_HEU_GCD'):
#    1552             try:
# -> 1553                 return dmp_zz_heu_gcd(f, g, u, K)
#    1554             except HeuristicGCDFailed:
#    1555                 pass
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1309         return dup_zz_heu_gcd(f, g, K)
#    1310
# -> 1311     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1312
#    1313     if result is not None:
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     909         return dmp_one(u, K), f, g
#     910     elif query('USE_SIMPLIFY_GCD'):
# --> 911         return _dmp_simplify_gcd(f, g, u, K)
#     912     else:
#     913         return None
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     955
#     956     v = u - 1
# --> 957     h = dmp_gcd(F, G, v, K)
#     958
#     959     cff = [ dmp_quo(cf, h, v, K) for cf in f ]
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_gcd(f, g, u, K)
#    1623
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#    1626
#    1627
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1582
#    1583     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1585
#    1586     return (dmp_inflate(h, J, u, K),
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1551         if K.is_ZZ and query('USE_HEU_GCD'):
#    1552             try:
# -> 1553                 return dmp_zz_heu_gcd(f, g, u, K)
#    1554             except HeuristicGCDFailed:
#    1555                 pass
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1309         return dup_zz_heu_gcd(f, g, K)
#    1310
# -> 1311     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1312
#    1313     if result is not None:
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     909         return dmp_one(u, K), f, g
#     910     elif query('USE_SIMPLIFY_GCD'):
# --> 911         return _dmp_simplify_gcd(f, g, u, K)
#     912     else:
#     913         return None
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     951             G = dmp_content(g, u, K)
#     952         else:
# --> 953             F = dmp_content(f, u, K)
#     954             G = dmp_LC(g, K)
#     955
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_content(f, u, K)
#    1791
#    1792     for c in f[1:]:
# -> 1793         cont = dmp_gcd(cont, c, v, K)
#    1794
#    1795         if dmp_one_p(cont, v, K):
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_gcd(f, g, u, K)
#    1623
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#    1626
#    1627
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1582
#    1583     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1585
#    1586     return (dmp_inflate(h, J, u, K),
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1551         if K.is_ZZ and query('USE_HEU_GCD'):
#    1552             try:
# -> 1553                 return dmp_zz_heu_gcd(f, g, u, K)
#    1554             except HeuristicGCDFailed:
#    1555                 pass
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1309         return dup_zz_heu_gcd(f, g, K)
#    1310
# -> 1311     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1312
#    1313     if result is not None:
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     909         return dmp_one(u, K), f, g
#     910     elif query('USE_SIMPLIFY_GCD'):
# --> 911         return _dmp_simplify_gcd(f, g, u, K)
#     912     else:
#     913         return None
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     949         if not df:
#     950             F = dmp_LC(f, K)
# --> 951             G = dmp_content(g, u, K)
#     952         else:
#     953             F = dmp_content(f, u, K)
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_content(f, u, K)
#    1791
#    1792     for c in f[1:]:
# -> 1793         cont = dmp_gcd(cont, c, v, K)
#    1794
#    1795         if dmp_one_p(cont, v, K):
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_gcd(f, g, u, K)
#    1623
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#    1626
#    1627
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1582
#    1583     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1585
#    1586     return (dmp_inflate(h, J, u, K),
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1551         if K.is_ZZ and query('USE_HEU_GCD'):
#    1552             try:
# -> 1553                 return dmp_zz_heu_gcd(f, g, u, K)
#    1554             except HeuristicGCDFailed:
#    1555                 pass
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1309         return dup_zz_heu_gcd(f, g, K)
#    1310
# -> 1311     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1312
#    1313     if result is not None:
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     909         return dmp_one(u, K), f, g
#     910     elif query('USE_SIMPLIFY_GCD'):
# --> 911         return _dmp_simplify_gcd(f, g, u, K)
#     912     else:
#     913         return None
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     949         if not df:
#     950             F = dmp_LC(f, K)
# --> 951             G = dmp_content(g, u, K)
#     952         else:
#     953             F = dmp_content(f, u, K)
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_content(f, u, K)
#    1791
#    1792     for c in f[1:]:
# -> 1793         cont = dmp_gcd(cont, c, v, K)
#    1794
#    1795         if dmp_one_p(cont, v, K):
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_gcd(f, g, u, K)
#    1623
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#    1626
#    1627
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1582
#    1583     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1585
#    1586     return (dmp_inflate(h, J, u, K),
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1551         if K.is_ZZ and query('USE_HEU_GCD'):
#    1552             try:
# -> 1553                 return dmp_zz_heu_gcd(f, g, u, K)
#    1554             except HeuristicGCDFailed:
#    1555                 pass
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1309         return dup_zz_heu_gcd(f, g, K)
#    1310
# -> 1311     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1312
#    1313     if result is not None:
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     909         return dmp_one(u, K), f, g
#     910     elif query('USE_SIMPLIFY_GCD'):
# --> 911         return _dmp_simplify_gcd(f, g, u, K)
#     912     else:
#     913         return None
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     955
#     956     v = u - 1
# --> 957     h = dmp_gcd(F, G, v, K)
#     958
#     959     cff = [ dmp_quo(cf, h, v, K) for cf in f ]
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_gcd(f, g, u, K)
#    1623
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#    1626
#    1627
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1582
#    1583     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1585
#    1586     return (dmp_inflate(h, J, u, K),
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1551         if K.is_ZZ and query('USE_HEU_GCD'):
#    1552             try:
# -> 1553                 return dmp_zz_heu_gcd(f, g, u, K)
#    1554             except HeuristicGCDFailed:
#    1555                 pass
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1309         return dup_zz_heu_gcd(f, g, K)
#    1310
# -> 1311     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1312
#    1313     if result is not None:
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     909         return dmp_one(u, K), f, g
#     910     elif query('USE_SIMPLIFY_GCD'):
# --> 911         return _dmp_simplify_gcd(f, g, u, K)
#     912     else:
#     913         return None
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     955
#     956     v = u - 1
# --> 957     h = dmp_gcd(F, G, v, K)
#     958
#     959     cff = [ dmp_quo(cf, h, v, K) for cf in f ]
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_gcd(f, g, u, K)
#    1623
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#    1626
#    1627
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1582
#    1583     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1585
#    1586     return (dmp_inflate(h, J, u, K),
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1551         if K.is_ZZ and query('USE_HEU_GCD'):
#    1552             try:
# -> 1553                 return dmp_zz_heu_gcd(f, g, u, K)
#    1554             except HeuristicGCDFailed:
#    1555                 pass
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1309         return dup_zz_heu_gcd(f, g, K)
#    1310
# -> 1311     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1312
#    1313     if result is not None:
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     909         return dmp_one(u, K), f, g
#     910     elif query('USE_SIMPLIFY_GCD'):
# --> 911         return _dmp_simplify_gcd(f, g, u, K)
#     912     else:
#     913         return None
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     957     h = dmp_gcd(F, G, v, K)
#     958
# --> 959     cff = [ dmp_quo(cf, h, v, K) for cf in f ]
#     960     cfg = [ dmp_quo(cg, h, v, K) for cg in g ]
#     961
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/euclidtools.py in <listcomp>(.0)
#     957     h = dmp_gcd(F, G, v, K)
#     958
# --> 959     cff = [ dmp_quo(cf, h, v, K) for cf in f ]
#     960     cfg = [ dmp_quo(cg, h, v, K) for cg in g ]
#     961
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/densearith.py in dmp_quo(f, g, u, K)
#    1669
#    1670     """
# -> 1671     return dmp_div(f, g, u, K)[0]
#    1672
#    1673
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/densearith.py in dmp_div(f, g, u, K)
#    1627         return dmp_ff_div(f, g, u, K)
#    1628     else:
# -> 1629         return dmp_rr_div(f, g, u, K)
#    1630
#    1631
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/polys/densearith.py in dmp_rr_div(f, g, u, K)
#    1400         _dr, dr = dr, dmp_degree(r, u)
#    1401
# -> 1402         if dr < dg:
#    1403             break
#    1404         elif not (dr < _dr):
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/core/decorators.py in _func(self, other)
#     265             if not isinstance(other, expectedcls):
#     266                 return retval
# --> 267             return func(self, other)
#     268
#     269         return _func
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/core/expr.py in __lt__(self, other)
#     373     def __lt__(self, other):
#     374         from .relational import StrictLessThan
# --> 375         return StrictLessThan(self, other)
#     376
#     377     def __trunc__(self):
#
# ~/.pyenv/versions/3.7.6/envs/rl/lib/python3.7/site-packages/sympy/core/relational.py in __new__(cls, lhs, rhs, **options)
#     697         if evaluate:
#     698             for me in (lhs, rhs):
# --> 699                 if me.is_extended_real is False:
#     700                     raise TypeError("Invalid comparison of non-real %s" % me)
#     701                 if me is S.NaN:
#
# KeyboardInterrupt:

# %%
agent = Agent(
    lr_actor=0.000025,
    lr_critic=0.00025,
    input_dims=[25],
    tau=0.001,
    env=env,
    batch_size=64,
    layer1_size=400,
    layer2_size=300,
    n_actions=5,
    chkpt_dir="/home/mans/Documents/ddpg/6"
)

# %%
np.random.seed(0)

# %%
liveloss = PlotLosses()

# %%
score_history = []

# %%
for i in range(100000):
    done = False
    score = 0
    obs = env.reset()
    agent.noise.reset()
    while not done:
        env.render()
        act = agent.choose_action(obs)
        new_state, reward, done, info = env.step(act)
        agent.remember(obs, act, reward, new_state, int(done))
        agent.learn()
        score += reward
        obs = new_state

    score_history.append(score)
    metrics = {"score_history": np.mean(score_history[-100:])}
    liveloss.update(metrics)
    liveloss.send()
    print(
        "episode",
        i,
        "score %.2f" % score,
        "100 game average %.2f" % np.mean(score_history[-100:]),
    )
    
    if i % 500 == 0:
        agent.save_models()
env.close()
